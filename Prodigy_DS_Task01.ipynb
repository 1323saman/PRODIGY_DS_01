# %%
import pandas as pd
data = pd.read_csv('global_biod_species_extinction_risks.csv')
data
# Out:
#                             species   parkpct        popden    eezpct  \
# 0        01-FULL-36-10b sp001785725  0.111888           NaN  0.681839
# 1       1-14-0-10-41-10 sp002773695  0.075862    324.278996  0.579310
# 2       1-14-0-20-39-34 sp002787355  0.105391   1428.741749  0.603205
# 3       1-14-2-50-48-13 sp002783265  0.600000     22.780310  1.000000
# 4        12-FULL-67-14b sp016871275  0.097115           NaN  0.668103
# ...                             ...       ...           ...       ...
# 597572             Zyzzyx chilensis  0.890100           NaN       NaN
# 597573             Zyzzyzus parvula  0.105263           NaN  0.894737
# 597574         Zyzzyzus rubusidaeus  0.453510  10913.987770  0.880455
# 597575             Zyzzyzus warreni  0.147784    321.172944  0.092674
# 597576                        spec.  0.086997   5705.121711       NaN
#
#           popshadow  totfishing  natfishing  popgroupmax  pthreat  \
# ...

# %%
data.head()
# Out:
#                        species   parkpct       popden    eezpct   popshadow  \
# 0   01-FULL-36-10b sp001785725  0.111888          NaN  0.681839  519.045361
# 1  1-14-0-10-41-10 sp002773695  0.075862   324.278996  0.579310  198.650358
# 2  1-14-0-20-39-34 sp002787355  0.105391  1428.741749  0.603205  800.471148
# 3  1-14-2-50-48-13 sp002783265  0.600000    22.780310  1.000000   90.493047
# 4   12-FULL-67-14b sp016871275  0.097115          NaN  0.668103  444.335993
#
#    totfishing  natfishing  popgroupmax  pthreat  d_assignedrisk         lcat
# 0  372.062448    0.043700          6.0     27.0             0.0  Ocean_Coast
# 1    0.404123    0.000000          4.0     54.0             0.0        Coast
# 2   99.788550    0.000198          6.0     46.0             0.0        Coast
# 3    0.315550    0.000000          4.0     69.0             0.0        Coast
# 4  161.876315    0.021687          6.0     25.0             0.0  Ocean_Coast

# %%
data.isnull().sum()
# Out:
# species                0
# parkpct              659
# popden             42416
# eezpct            431044
# popshadow         431044
# totfishing        431065
# natfishing        433002
# popgroupmax        10951
# pthreat              777
# d_assignedrisk       659
# lcat                 659
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 597577 entries, 0 to 597576
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   species         597577 non-null  object
#  1   parkpct         596918 non-null  float64
#  2   popden          555161 non-null  float64
#  3   eezpct          166533 non-null  float64
#  4   popshadow       166533 non-null  float64
#  5   totfishing      166512 non-null  float64
#  6   natfishing      164575 non-null  float64
#  7   popgroupmax     586626 non-null  float64
#  8   pthreat         596800 non-null  float64
#  9   d_assignedrisk  596918 non-null  float64
#  10  lcat            596918 non-null  object
# dtypes: float64(9), object(2)
# memory usage: 50.2+ MB

# %%
data.describe()
# Out:
#              parkpct        popden         eezpct      popshadow  \
# count  596918.000000  5.551610e+05  166533.000000  166533.000000
# mean        0.230795  2.727859e+03       0.487795    3460.939164
# std         0.222033  1.026865e+04       0.343550   11080.803842
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%         0.087365  3.283502e+02       0.139394     300.400502
# 50%         0.173914  1.084336e+03       0.524378    1108.369517
# 75%         0.286803  2.364651e+03       0.788889    2713.900982
# max         1.000000  1.223843e+06       1.000000  369020.500000
#
#           totfishing     natfishing    popgroupmax        pthreat  \
# count  166512.000000  164575.000000  586626.000000  596800.000000
# mean      372.463765       0.139743       5.491134      38.881516
# std      1779.761108       0.302809       2.203632      27.233256
# min         0.000000       0.000000       1.000000       0.000000
# ...

# %%
data.dropna()
# Out:
#                             species   parkpct        popden    eezpct  \
# 1       1-14-0-10-41-10 sp002773695  0.075862    324.278996  0.579310
# 2       1-14-0-20-39-34 sp002787355  0.105391   1428.741749  0.603205
# 3       1-14-2-50-48-13 sp002783265  0.600000     22.780310  1.000000
# 5       13-2-20CM-66-19 sp001914695  0.064242    879.118109  0.365543
# 6       2-01-FULL-39-33 sp002773855  0.065904    665.256847  0.388150
# ...                             ...       ...           ...       ...
# 597564            Zyzomys woodwardi  0.209926   1241.856021  0.217324
# 597568   Zyzzogeton quadrimaculatus  0.185792    297.235753  0.000000
# 597570            Zyzzya fuliginosa  0.000000  35284.355470  0.000000
# 597574         Zyzzyzus rubusidaeus  0.453510  10913.987770  0.880455
# 597575             Zyzzyzus warreni  0.147784    321.172944  0.092674
#
#           popshadow  totfishing  natfishing  popgroupmax  pthreat  \
# ...

# %%
print(data['lcat'].value_counts())
# Out:
# lcat
# Land_Coast          271574
# Land                158811
# Coast               127024
# Ocean_Coast          32111
# Ocean                 6840
# Land_Coast_Ocean       558
# Name: count, dtype: int64

# %%
print(data['popden'].describe())
# Out:
# count    5.551610e+05
# mean     2.727859e+03
# std      1.026865e+04
# min      0.000000e+00
# 25%      3.283502e+02
# 50%      1.084336e+03
# 75%      2.364651e+03
# max      1.223843e+06
# Name: popden, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bar chart
plt.figure(figsize=(8, 5))

sns.barplot(data= data, x='lcat', y='totfishing', estimator='mean', palette='viridis', errorbar=None)

plt.xlabel('Category')
plt.ylabel('Average Total Fishing Effort')
plt.title('Average Total Fishing by Category')
plt.show()

# %%
# Histogram

plt.figure(figsize=(8, 6))
sns.histplot(data=data, x='popden', hue='lcat', multiple='stack', bins=30, kde=False, alpha=0.6, palette='viridis')
plt.xlabel('Population Density')
plt.ylabel('Frequency')
plt.title('Histogram of Population Density by Category')
plt.show()
